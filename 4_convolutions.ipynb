# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():
    # Input data.
    tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    
    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    layer3_weights = tf.Variable(tf.truncated_normal([image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
    
    # Model.
    def model(data):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer1_biases)
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer2_biases)
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases
    
    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))

    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
    
    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.337578
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.4%
# Minibatch loss at step 50: 1.859231
# Minibatch accuracy: 25.0%
# Validation accuracy: 30.7%
# Minibatch loss at step 100: 1.148158
# Minibatch accuracy: 56.2%
# Validation accuracy: 67.9%
# Minibatch loss at step 150: 0.660749
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.2%
# Minibatch loss at step 200: 0.927481
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.8%
# Minibatch loss at step 250: 1.189743
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.9%
# Minibatch loss at step 300: 0.353903
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.9%
# Minibatch loss at step 350: 0.592864
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.0%
# Minibatch loss at step 400: 0.351811
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.9%
# Minibatch loss at step 450: 0.719391
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.9%
# Minibatch loss at step 500: 0.810051
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.3%
# Minibatch loss at step 550: 0.770117
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.8%
# Minibatch loss at step 600: 0.385293
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.5%
# Minibatch loss at step 650: 0.825712
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.2%
# Minibatch loss at step 700: 0.990098
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.8%
# Minibatch loss at step 750: 0.076798
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 800: 0.565774
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.5%
# Minibatch loss at step 850: 0.834173
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.8%
# Minibatch loss at step 900: 0.504954
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.4%
# Minibatch loss at step 950: 0.545412
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.5%
# Minibatch loss at step 1000: 0.404396
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.6%
# Test accuracy: 89.7%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():
    # Input data.
    tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    
    # Variables.
    layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    layer3_weights = tf.Variable(tf.truncated_normal([image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    layer4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
    
    # Model.
    def model(data):
        conv_1 = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        hidden_1 = tf.nn.relu(conv_1 + layer1_biases)
        pool_1 = tf.nn.max_pool(hidden_1, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        conv_2 = tf.nn.conv2d(pool_1, layer2_weights, [1, 1, 1, 1], padding='SAME')
        hidden_2 = tf.nn.relu(conv_2 + layer2_biases)
        pool_2 = tf.nn.max_pool(hidden_2, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        shape = pool_2.get_shape().as_list()
        reshape = tf.reshape(pool_2, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden_3 = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden_3, layer4_weights) + layer4_biases    
    
    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))

    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
    
    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 4.393198
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.002405
# Minibatch accuracy: 25.0%
# Validation accuracy: 34.1%
# Minibatch loss at step 100: 1.299397
# Minibatch accuracy: 56.2%
# Validation accuracy: 55.9%
# Minibatch loss at step 150: 0.637118
# Minibatch accuracy: 87.5%
# Validation accuracy: 71.3%
# Minibatch loss at step 200: 0.942821
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.0%
# Minibatch loss at step 250: 1.331441
# Minibatch accuracy: 62.5%
# Validation accuracy: 79.5%
# Minibatch loss at step 300: 0.444354
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.3%
# Minibatch loss at step 350: 0.463246
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.5%
# Minibatch loss at step 400: 0.235546
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.3%
# Minibatch loss at step 450: 0.898684
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.1%
# Minibatch loss at step 500: 0.784113
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.5%
# Minibatch loss at step 550: 0.732499
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 600: 0.258805
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.4%
# Minibatch loss at step 650: 0.777573
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 700: 0.737793
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.0%
# Minibatch loss at step 750: 0.035483
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.9%
# Minibatch loss at step 800: 0.575514
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.1%
# Minibatch loss at step 850: 0.990541
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.9%
# Minibatch loss at step 900: 0.641122
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.3%
# Minibatch loss at step 950: 0.624700
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.5%
# Minibatch loss at step 1000: 0.374204
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.0%
# Test accuracy: 90.7%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():
    # Input data.
    tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    
    # Variables.
    global_step = tf.Variable(0)
    layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    layer3_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
    layer4_weights = tf.Variable(tf.truncated_normal([image_size // 7 * image_size // 7 * depth, num_hidden], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    layer5_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
    layer5_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
    
    # Model.
    def model(data, mode = 'train'):
        conv_1 = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
        if mode is 'train':
            hidden_1 = tf.nn.dropout(tf.nn.relu(conv_1 + layer1_biases), 0.7)
        else:
            hidden_1 = tf.nn.relu(conv_1 + layer1_biases)
        
        
        conv_2 = tf.nn.conv2d(hidden_1, layer2_weights, [1, 2, 2, 1], padding='SAME')
        if mode is 'train':
            hidden_2 = tf.nn.dropout(tf.nn.relu(conv_2 + layer2_biases), .7)
        else:
            hidden_2 = tf.nn.relu(conv_2 + layer2_biases)
        
        
        conv_3 = tf.nn.conv2d(hidden_2, layer3_weights, [1, 2, 2, 1], padding='SAME')
        if mode is 'train':
            hidden_3 = tf.nn.dropout(tf.nn.relu(conv_3 + layer3_biases), .7)
        else:
            hidden_3 = tf.nn.relu(conv_3 + layer3_biases)
        
        shape = hidden_3.get_shape().as_list()
        reshape = tf.reshape(hidden_3, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden_4 = tf.nn.relu(tf.matmul(reshape, layer4_weights) + layer4_biases)
        return tf.matmul(hidden_4, layer5_weights) + layer5_biases    
    
    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))

    # Optimizer.
    learning_rate = tf.train.exponential_decay(0.1, global_step, 1000, 0.85, staircase=True)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
    
    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset, 'valid'))
    test_prediction = tf.nn.softmax(model(tf_test_dataset, 'test'))

# %%
num_steps = 3001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 4.177548
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.338955
# Minibatch accuracy: 6.2%
# Validation accuracy: 19.1%
# Minibatch loss at step 100: 1.911700
# Minibatch accuracy: 37.5%
# Validation accuracy: 45.8%
# Minibatch loss at step 150: 0.952670
# Minibatch accuracy: 75.0%
# Validation accuracy: 63.0%
# Minibatch loss at step 200: 1.261478
# Minibatch accuracy: 68.8%
# Validation accuracy: 69.6%
# Minibatch loss at step 250: 1.717931
# Minibatch accuracy: 56.2%
# Validation accuracy: 71.1%
# Minibatch loss at step 300: 0.671798
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.6%
# Minibatch loss at step 350: 0.849505
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 400: 0.463800
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.9%
# Minibatch loss at step 450: 1.278377
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.8%
# Minibatch loss at step 500: 0.998857
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.0%
# Minibatch loss at step 550: 1.053116
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.5%
# Minibatch loss at step 600: 0.335489
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.9%
# Minibatch loss at step 650: 1.033785
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.1%
# Minibatch loss at step 700: 1.512501
# Minibatch accuracy: 56.2%
# Validation accuracy: 81.1%
# Minibatch loss at step 750: 0.120114
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.7%
# Minibatch loss at step 800: 0.758718
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.7%
# Minibatch loss at step 850: 1.194883
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.9%
# Minibatch loss at step 900: 1.027343
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.2%
# Minibatch loss at step 950: 0.594854
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 1000: 0.310575
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.6%
# Minibatch loss at step 1050: 0.640509
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.8%
# Minibatch loss at step 1100: 1.364140
# Minibatch accuracy: 56.2%
# Validation accuracy: 81.0%
# Minibatch loss at step 1150: 0.425638
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.8%
# Minibatch loss at step 1200: 1.370683
# Minibatch accuracy: 50.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 1250: 0.551169
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# Minibatch loss at step 1300: 0.266982
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.5%
# Minibatch loss at step 1350: 0.905493
# Minibatch accuracy: 62.5%
# Validation accuracy: 82.2%
# Minibatch loss at step 1400: 0.404138
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.2%
# Minibatch loss at step 1450: 0.498845
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.5%
# Minibatch loss at step 1500: 0.665501
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.9%
# Minibatch loss at step 1550: 0.507704
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.0%
# Minibatch loss at step 1600: 0.841273
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.2%
# Minibatch loss at step 1650: 1.027493
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.3%
# Minibatch loss at step 1700: 0.543805
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.4%
# Minibatch loss at step 1750: 0.620784
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.7%
# Minibatch loss at step 1800: 0.607994
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.8%
# Minibatch loss at step 1850: 0.838511
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.4%
# Minibatch loss at step 1900: 0.463221
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.5%
# Minibatch loss at step 1950: 0.540152
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.8%
# Minibatch loss at step 2000: 0.161553
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.2%
# Minibatch loss at step 2050: 0.649051
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.4%
# Minibatch loss at step 2100: 0.577261
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.2%
# Minibatch loss at step 2150: 0.599168
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.1%
# Minibatch loss at step 2200: 0.319528
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.0%
# Minibatch loss at step 2250: 0.546747
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.3%
# Minibatch loss at step 2300: 0.526423
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.6%
# Minibatch loss at step 2350: 0.514940
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.6%
# Minibatch loss at step 2400: 0.751939
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.7%
# Minibatch loss at step 2450: 0.616513
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.8%
# Minibatch loss at step 2500: 1.053250
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.0%
# Minibatch loss at step 2550: 0.931386
# Minibatch accuracy: 62.5%
# Validation accuracy: 84.5%
# Minibatch loss at step 2600: 0.123954
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.7%
# Minibatch loss at step 2650: 0.162880
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.7%
# Minibatch loss at step 2700: 0.567398
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.6%
# Minibatch loss at step 2750: 1.230208
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.5%
# Minibatch loss at step 2800: 0.572771
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.9%
# Minibatch loss at step 2850: 0.172221
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.0%
# Minibatch loss at step 2900: 0.558834
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.9%
# Minibatch loss at step 2950: 0.508280
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 3000: 0.445378
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.9%
# Test accuracy: 91.9%
