# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
        statinfo = os.stat(filename)
        if statinfo.st_size == expected_bytes:
            print('Found and verified %s' % filename)
        else:
            print(statinfo.st_size)
            raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5240, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:32]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'UNK', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a', 'term', 'abuse', 'of', 'first', 'abuse', 'used', 'first', 'against']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of']
#     labels: ['anarchism', 'a', 'term', 'originated', 'term', 'originated', 'as', 'of', 'abuse', 'a', 'as', 'of', 'first', 'a', 'abuse', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)  
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed, labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.729643
# Nearest to so: titanium, narcotic, tommaso, consanguinity, aleph, heine, cour, phd,
# Nearest to system: stanislavsky, polybius, douard, monastics, unconscious, sensory, dario, fingerprinting,
# Nearest to i: accession, rabbinic, booked, reassessment, couturat, invites, flicker, hom,
# Nearest to used: synonym, maharal, samarkand, maser, responses, tomography, compressor, anubis,
# Nearest to was: po, pentagons, vest, costello, nonsignatory, kangaroo, expanding, reassignment,
# Nearest to UNK: diamagnetic, soares, auguste, reliable, rube, easy, clowns, cinematography,
# Nearest to when: faire, malarial, receptacle, memorable, diplomat, arthur, sovereigns, types,
# Nearest to while: inherently, nicephorus, troubled, manasseh, clausewitz, ega, minuteman, geosynchronous,
# Nearest to as: kirwan, branch, vertebrae, embarrassed, wavefunction, plumb, dwarfed, judo,
# Nearest to have: texaco, allied, would, johan, uptake, oman, synonymously, nasr,
# Nearest to all: detached, monkeys, botswana, trapezohedron, trough, cartridge, prolific, infante,
# Nearest to b: aggregates, gadamer, partita, westeros, rationalism, irreversibly, sacked, bertie,
# Nearest to can: complexes, bourgeoisie, theologies, berg, kuala, yeats, pontifex, samaritan,
# Nearest to their: amu, socio, respects, nauru, hapless, momentarily, garcia, functor,
# Nearest to use: penalized, hakama, scientific, higham, misplaced, bicycle, gilda, glamorgan,
# Nearest to state: italy, lucia, unwillingness, gpcrs, library, deride, favre, nightmares,
# Average loss at step 2000: 4.413108
# Average loss at step 4000: 3.925442
# Average loss at step 6000: 3.664608
# Average loss at step 8000: 3.714428
# Average loss at step 10000: 3.666281
# Nearest to so: titanium, smoothness, consanguinity, aleph, narcotic, flourishing, heine, cour,
# Nearest to system: stanislavsky, sensory, unconscious, persuade, polybius, different, second, latex,
# Nearest to i: invites, real, accession, reassessment, he, stewards, lagrange, ligatures,
# Nearest to used: alumina, hospital, available, known, belloc, si, chance, odense,
# Nearest to was: is, has, were, had, schleicher, by, gay, when,
# Nearest to UNK: cheating, facility, impression, de, commemorative, joining, carcinogens, akkadian,
# Nearest to when: where, strikes, ttt, was, sovereigns, batch, coax, hf,
# Nearest to while: inherently, at, chlorophyll, senescence, former, succeed, am, thousandth,
# Nearest to as: embarrassed, phone, aaa, override, lyme, became, davidians, juices,
# Nearest to have: had, has, were, be, allied, are, rias, metrication,
# Nearest to all: patrician, monkeys, ill, believes, detached, educating, imagery, aberfoyle,
# Nearest to b: faithless, checking, rationalism, gadamer, x, martini, som, waned,
# Nearest to can: may, will, would, should, must, hypnotism, unveiling, pasiphae,
# Nearest to their: its, his, the, needle, untold, tax, raiding, amendments,
# Nearest to use: penalized, delivery, hakama, cosmography, characters, alarm, admissible, committees,
# Nearest to state: lucia, italy, horowitz, library, unwillingness, est, chong, sheryl,
# Average loss at step 12000: 3.650582
# Average loss at step 14000: 3.642100
# Average loss at step 16000: 3.564026
# Average loss at step 18000: 3.585841
# Average loss at step 20000: 3.464832
# Nearest to so: titanium, smoothness, consanguinity, flourishing, nonaggression, maltose, aleph, toon,
# Nearest to system: stanislavsky, sensory, unconscious, persuade, fingerprinting, polybius, systems, ghb,
# Nearest to i: ligatures, lagrange, accession, invites, he, stewards, you, they,
# Nearest to used: known, alumina, available, valproate, accepted, formed, considered, experienced,
# Nearest to was: is, were, had, has, schleicher, became, gay, be,
# Nearest to UNK: de, looksmart, gonzales, canidae, celebrate, cyan, scalability, requiring,
# Nearest to when: if, where, that, after, chest, mitchell, jointly, before,
# Nearest to while: inherently, am, wideband, pun, pilgrims, eclac, dharma, proxies,
# Nearest to as: lobe, alternative, vertebrae, override, by, davidians, widgery, fatty,
# Nearest to have: had, has, were, be, are, metrication, rias, hasbro,
# Nearest to all: some, these, imagery, naturalists, jhanas, functors, their, harbors,
# Nearest to b: faithless, norsemen, waned, martini, kilobytes, x, checking, awry,
# Nearest to can: may, will, would, must, should, could, cannot, might,
# Nearest to their: its, his, her, the, some, many, kabbalists, amendments,
# Nearest to use: penalized, create, return, delivery, cosmography, corrects, rest, oglethorpe,
# Nearest to state: lucia, sheryl, delimitation, library, italy, transfusion, mancha, ryu,
# Average loss at step 22000: 3.413554
# Average loss at step 24000: 3.535074
# Average loss at step 26000: 3.424340
# Average loss at step 28000: 3.413000
# Average loss at step 30000: 3.459702
# Nearest to so: smoothness, titanium, flemish, maltose, spent, heine, weird, nonaggression,
# Nearest to system: systems, revolts, stanislavsky, persuade, fingerprinting, rust, yastrzemski, xf,
# Nearest to i: p, ii, gico, stewards, t, assigns, you, haile,
# Nearest to used: available, formed, considered, known, alumina, found, regarded, valproate,
# Nearest to was: is, has, were, had, became, got, been, when,
# Nearest to UNK: no, hennig, com, bulge, done, homeless, jets, luxuriant,
# Nearest to when: if, after, where, while, before, because, chest, mitchell,
# Nearest to while: when, although, but, saw, and, pun, eclac, gfdl,
# Nearest to as: contentious, vertebrae, courland, senseless, aaa, alternative, when, before,
# Nearest to have: had, has, were, be, are, having, hasbro, gere,
# Nearest to all: these, some, various, patrician, quod, many, magick, consolidating,
# Nearest to b: d, and, kilns, coastal, lewis, sacked, f, bertie,
# Nearest to can: may, will, would, must, should, could, cannot, might,
# Nearest to their: his, its, her, the, some, jdk, capricornus, these,
# Nearest to use: return, cosmography, penalized, end, faro, change, course, detect,
# Nearest to state: library, delimitation, sheryl, italy, arcs, lucia, transfusion, unifies,
# Average loss at step 32000: 3.420260
# Average loss at step 34000: 3.513937
# Average loss at step 36000: 3.444626
# Average loss at step 38000: 3.452739
# Average loss at step 40000: 3.234603
# Nearest to so: smoothness, if, maltose, satirists, titanium, overlord, flemish, consanguinity,
# Nearest to system: systems, persuade, consumers, revolts, stanislavsky, worships, global, avalon,
# Nearest to i: ii, p, we, t, stewards, commodore, g, they,
# Nearest to used: known, regarded, considered, available, applied, responsible, formed, found,
# Nearest to was: is, were, had, became, has, been, by, be,
# Nearest to UNK: photolithography, patel, gust, bung, corrupting, lug, j, honorably,
# Nearest to when: if, after, where, while, before, with, mitchell, scotsman,
# Nearest to while: although, when, though, however, saw, gfdl, if, pilgrims,
# Nearest to as: contentious, when, lobe, harmed, vertebrae, bundaberg, senseless, became,
# Nearest to have: had, has, were, be, are, having, codebreakers, refer,
# Nearest to all: these, some, both, various, many, naturalists, several, eastern,
# Nearest to b: d, c, lewis, smoked, monies, kilns, circumcised, f,
# Nearest to can: will, may, would, must, could, should, cannot, might,
# Nearest to their: its, his, her, the, some, jdk, your, amendments,
# Nearest to use: return, detect, cosmography, change, end, reintroduce, method, penalized,
# Nearest to state: transfusion, sheryl, lucia, italy, curve, upa, delimitation, proceedings,
# Average loss at step 42000: 3.471518
# Average loss at step 44000: 3.430701
# Average loss at step 46000: 3.464276
# Average loss at step 48000: 3.462722
# Average loss at step 50000: 3.447482
# Nearest to so: too, thus, maltose, spent, smoothness, nonaggression, overlord, mononoke,
# Nearest to system: systems, consumers, ghb, emo, rust, stanislavsky, sentences, spousal,
# Nearest to i: we, ii, you, they, dystrophy, she, lorenzo, t,
# Nearest to used: known, responsible, regarded, available, considered, applied, called, accepted,
# Nearest to was: is, has, were, had, be, became, been, although,
# Nearest to UNK: memel, bunker, igneous, dagestan, ing, junkers, du, metrical,
# Nearest to when: if, while, where, before, after, although, though, during,
# Nearest to while: when, although, though, downloads, however, saw, ek, at,
# Nearest to as: lobe, contentious, when, curtailing, before, antipope, kabbalistic, became,
# Nearest to have: had, has, were, be, are, having, depose, codebreakers,
# Nearest to all: both, many, these, some, various, several, tabled, rakyat,
# Nearest to b: d, c, f, monies, lewis, r, x, cdot,
# Nearest to can: may, will, would, must, could, should, cannot, might,
# Nearest to their: its, his, her, the, your, many, our, whose,
# Nearest to use: return, change, detect, end, speed, cosmography, rosenbaum, faro,
# Nearest to state: lucia, pouches, iia, city, delimitation, prosecution, states, parliamentary,
# Average loss at step 52000: 3.403469
# Average loss at step 54000: 3.291428
# Average loss at step 56000: 3.398490
# Average loss at step 58000: 3.423193
# Average loss at step 60000: 3.371850
# Nearest to so: too, thus, if, spent, draws, cosmic, grids, nonaggression,
# Nearest to system: systems, ghb, consumers, rust, excursions, professes, humiliation, computer,
# Nearest to i: ii, we, dystrophy, you, lorenzo, laszlo, chronic, fernandez,
# Nearest to used: known, responsible, applied, available, regarded, considered, written, found,
# Nearest to was: is, were, became, had, has, be, been, ethicists,
# Nearest to UNK: ariel, cormac, bergen, dagestan, yates, hooded, ernie, ashton,
# Nearest to when: while, if, where, before, after, because, although, during,
# Nearest to while: although, when, but, though, however, before, where, and,
# Nearest to as: lobe, blemish, vertebrae, franchisor, before, harmed, bius, kirwan,
# Nearest to have: had, has, were, be, are, having, depose, snowfall,
# Nearest to all: both, some, many, various, these, several, any, were,
# Nearest to b: d, c, k, f, h, monies, lewis, cdot,
# Nearest to can: will, may, could, would, must, should, cannot, might,
# Nearest to their: its, his, her, your, the, whose, some, several,
# Nearest to use: detect, return, change, method, stg, ancestor, reintroduce, boac,
# Nearest to state: city, government, iia, delimitation, sheryl, rentals, arcs, states,
# Average loss at step 62000: 3.353504
# Average loss at step 64000: 3.398053
# Average loss at step 66000: 3.386032
# Average loss at step 68000: 3.404505
# Average loss at step 70000: 3.395071
# Nearest to so: thus, too, grids, nonaggression, happier, sometimes, cooler, mononoke,
# Nearest to system: systems, ghb, consumers, process, excursions, rust, mailing, humiliation,
# Nearest to i: ii, we, you, t, they, chronic, g, v,
# Nearest to used: known, applied, responsible, available, found, regarded, considered, called,
# Nearest to was: is, had, became, has, were, be, did, when,
# Nearest to UNK: junkers, codepoint, kor, cormac, protesting, wahhabis, surrenders, eusebio,
# Nearest to when: if, while, where, before, after, although, because, however,
# Nearest to while: although, when, however, though, before, but, if, and,
# Nearest to as: contentious, lobe, blemish, videogame, cyclone, when, wojciech, like,
# Nearest to have: had, has, were, be, are, having, simmered, depose,
# Nearest to all: both, various, many, some, these, descent, most, several,
# Nearest to b: d, c, f, k, cdot, e, lewis, g,
# Nearest to can: may, will, could, would, must, should, cannot, might,
# Nearest to their: its, his, her, your, whose, my, the, our,
# Nearest to use: change, method, detect, stg, involve, ancestor, cloning, value,
# Nearest to state: city, rentals, states, iia, inactivity, empiricists, parliamentary, government,
# Average loss at step 72000: 3.312358
# Average loss at step 74000: 3.291222
# Average loss at step 76000: 3.378132
# Average loss at step 78000: 3.305567
# Average loss at step 80000: 3.347800
# Nearest to so: thus, too, cooler, grids, sometimes, writes, mononoke, exaggerating,
# Nearest to system: systems, ghb, process, rust, excursions, indirectly, mailing, professes,
# Nearest to i: we, ii, g, you, n, t, maglev, p,
# Nearest to used: applied, responsible, known, available, regarded, found, considered, required,
# Nearest to was: is, were, had, has, became, by, did, be,
# Nearest to UNK: du, inroads, jai, satire, references, circumvented, kingman, motherland,
# Nearest to when: if, before, after, while, where, although, since, however,
# Nearest to while: although, however, when, though, but, before, were, since,
# Nearest to as: vertebrae, curtailing, interviewing, fibrous, promo, lobe, fangio, before,
# Nearest to have: had, has, are, were, be, having, produce, codebreakers,
# Nearest to all: both, various, some, many, these, every, any, each,
# Nearest to b: c, f, d, k, p, cdot, n, r,
# Nearest to can: will, could, may, must, would, should, cannot, might,
# Nearest to their: its, his, her, your, our, whose, the, my,
# Nearest to use: method, most, cloning, value, detect, return, telecommunications, hotspur,
# Nearest to state: states, city, government, iia, inactivity, budge, pouches, parliamentary,
# Average loss at step 82000: 3.316041
# Average loss at step 84000: 3.351674
# Average loss at step 86000: 3.104285
# Average loss at step 88000: 2.859407
# Average loss at step 90000: 3.090847
# Nearest to so: too, thus, grids, sometimes, before, probably, cooler, less,
# Nearest to system: systems, process, ghb, excursions, professes, indirectly, consumers, rust,
# Nearest to i: ii, we, you, t, she, they, v, gico,
# Nearest to used: applied, known, responsible, considered, regarded, available, called, seen,
# Nearest to was: is, had, became, were, has, although, did, been,
# Nearest to UNK: libertine, aristocratic, uno, sociologist, beaulieu, ariel, aeschylus, contended,
# Nearest to when: if, before, after, while, where, although, during, though,
# Nearest to while: although, when, however, but, though, before, where, and,
# Nearest to as: mackaye, lobe, ribbentrop, after, baths, becomes, contentious, before,
# Nearest to have: had, has, be, having, are, include, produce, were,
# Nearest to all: both, various, these, many, some, several, every, gearbox,
# Nearest to b: d, and, in, chisinau, bertie, nicolas, jakob, danish,
# Nearest to can: could, will, would, must, should, may, cannot, might,
# Nearest to their: his, its, her, your, our, the, my, several,
# Nearest to use: method, value, hotspur, support, cotangent, cloning, detect, automata,
# Nearest to state: city, states, slap, iia, pouches, budge, government, proceedings,
# Average loss at step 92000: 3.085788
# Average loss at step 94000: 3.258656
# Average loss at step 96000: 3.276747
# Average loss at step 98000: 3.310028
# Average loss at step 100000: 3.228188
# Nearest to so: too, thus, grids, sometimes, alameda, cooler, heuristics, mohel,
# Nearest to system: systems, process, ghb, situation, network, excursions, state, units,
# Nearest to i: we, ii, you, t, they, she, chronic, v,
# Nearest to used: applied, known, regarded, responsible, called, considered, seen, done,
# Nearest to was: is, were, has, had, became, been, be, although,
# Nearest to UNK: fernandez, prey, memel, patel, sherwood, tires, el, sumerians,
# Nearest to when: while, if, after, before, although, where, though, because,
# Nearest to while: although, when, though, however, and, before, but, where,
# Nearest to as: renminbi, raison, including, blemish, vertebrae, ltspkr, lobe, fibrous,
# Nearest to have: had, has, be, are, include, were, refer, produce,
# Nearest to all: both, various, many, these, some, gearbox, several, each,
# Nearest to b: d, krakatoa, flynn, chisinau, singer, nicolas, bertie, canids,
# Nearest to can: could, will, must, would, should, cannot, may, might,
# Nearest to their: its, his, her, your, the, our, whose, several,
# Nearest to use: support, automata, cloning, way, cotangent, method, hotspur, value,
# Nearest to state: states, iia, city, legislative, government, slap, pouches, republic,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
    global data_index
    span = 2 * bag_window + 1 # [ bag_window target bag_window ]
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        # just for testing
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(bag_window)
        batch[i] = buffer_list
        # iterate to the next buffer
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))  
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size], dtype = tf.float32))
    # Model.
    # Look up embeddings for inputs.
    embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    red_sum = tf.reduce_sum(embeds, 1)
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.to_float(train_labels), red_sum, num_sampled, vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, 2)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.683880
# Nearest to nine: bau, yorkist, cambodia, mahogany, gluons, leftrightarrow, wore, disillusionment,
# Nearest to its: standard, kelvins, hesperides, reuven, courtiers, igm, learner, drexler,
# Nearest to while: ict, decline, religious, widowers, bastille, gig, projectors, timbre,
# Nearest to by: posthumously, barnabas, parallelism, normalised, airtight, snapper, wolfman, lowest,
# Nearest to an: viva, drove, keeling, scuderia, aristocrat, angst, dreyfus, vincendeau,
# Nearest to zero: evaluated, fta, gallia, bargain, leno, feist, urchin, photonic,
# Nearest to his: guiding, chlamydia, ming, normandie, lil, fold, shepherd, stanis,
# Nearest to that: danielle, emphasises, investigating, franca, coerce, miletus, butler, banco,
# Nearest to this: evidentiary, fiduciary, proclus, opportunity, assumption, davenport, muriel, theologians,
# Nearest to the: cocoon, expectations, deems, lookahead, diffraction, templars, ticino, illuminated,
# Nearest to were: predictable, andropov, negating, mobility, consoles, afoul, ulyanov, directly,
# Nearest to united: krupp, illinois, taggart, tenochtitl, curator, transshipment, christy, arabella,
# Nearest to as: snows, miami, pubs, spinner, travis, fitz, recension, parodying,
# Nearest to history: admixture, starbucks, marconi, xenophobic, hartnell, clergy, alkyl, abe,
# Nearest to been: viking, counsellor, why, terminology, iambic, responsiveness, investiture, sola,
# Nearest to it: ansi, geschichte, arminian, basques, tsunamis, frieze, gibraltar, difference,
# Average loss at step 2000: 4.600894
# Average loss at step 4000: 3.932574
# Average loss at step 6000: 3.721766
# Average loss at step 8000: 3.527393
# Average loss at step 10000: 3.477559
# Nearest to nine: eight, seven, six, zero, five, four, two, three,
# Nearest to its: their, his, the, her, colombo, alles, satirized, resigns,
# Nearest to while: bergen, around, saudis, pondicherry, rooms, though, crandall, attributed,
# Nearest to by: who, adheres, dvd, appia, gilchrist, inlet, tilden, usury,
# Nearest to an: a, the, dactylic, another, any, nk, cochrane, mpls,
# Nearest to zero: four, five, nine, seven, eight, six, two, three,
# Nearest to his: their, its, her, the, varepsilon, keypad, darwinism, opiate,
# Nearest to that: which, who, this, basie, nosed, commensurate, colloquium, when,
# Nearest to this: it, which, a, the, that, greaves, crumbled, frenetic,
# Nearest to the: a, its, an, any, another, this, his, crossings,
# Nearest to were: are, was, is, had, programmes, be, sailboat, conspired,
# Nearest to united: illinois, krupp, cet, corrino, regulars, carolla, advises, caches,
# Nearest to as: glasgow, max, larp, chemotherapeutic, stephanie, eds, overly, pneumonic,
# Nearest to history: endocarditis, unambiguously, partisan, backpack, niggers, sandman, zhang, starbucks,
# Nearest to been: thinning, become, sse, be, scale, emu, blitter, tippit,
# Nearest to it: he, there, this, she, cdp, they, warnings, alzheimer,
# Average loss at step 12000: 3.488538
# Average loss at step 14000: 3.439061
# Average loss at step 16000: 3.429671
# Average loss at step 18000: 3.395203
# Average loss at step 20000: 3.213964
# Nearest to nine: eight, seven, zero, two, three, six, five, four,
# Nearest to its: their, his, the, her, nihon, our, pardoned, soundhole,
# Nearest to while: though, when, and, but, although, before, if, heartbeat,
# Nearest to by: inlet, when, and, jelly, against, inteligencia, usury, multiplayer,
# Nearest to an: another, electrification, archie, cordilleras, mpls, dreyfus, drove, heidelberg,
# Nearest to zero: seven, eight, nine, five, six, three, four, two,
# Nearest to his: their, her, the, its, attain, s, any, my,
# Nearest to that: which, this, however, what, when, where, vic, because,
# Nearest to this: that, which, it, the, greaves, inoue, magazine, fabien,
# Nearest to the: his, their, its, a, her, crossings, any, each,
# Nearest to were: are, was, is, include, been, have, subplot, be,
# Nearest to united: krupp, defends, illinois, corrino, heartfelt, ante, advises, supergroup,
# Nearest to as: intermarriage, nameless, hund, call, distantly, angelic, nicotine, carroll,
# Nearest to history: list, consisting, sleepers, endocarditis, establishment, partisan, poisons, entomology,
# Nearest to been: become, were, thinning, was, be, roxy, loosely, preferentially,
# Nearest to it: he, she, this, there, fcc, cortona, grabbed, mitterrand,
# Average loss at step 22000: 3.355213
# Average loss at step 24000: 3.291746
# Average loss at step 26000: 3.244425
# Average loss at step 28000: 3.290703
# Average loss at step 30000: 3.211066
# Nearest to nine: eight, six, seven, five, zero, four, th, three,
# Nearest to its: their, his, her, the, my, mawr, our, satirized,
# Nearest to while: and, although, though, abbas, germanicus, after, like, concentrates,
# Nearest to by: through, who, against, silas, winston, has, rickshaws, lends,
# Nearest to an: another, the, a, electrification, heidelberg, roofs, sanctity, impart,
# Nearest to zero: five, eight, seven, six, nine, four, three, two,
# Nearest to his: their, her, its, my, s, the, judaism, keypad,
# Nearest to that: which, who, where, this, basie, however, because, vic,
# Nearest to this: it, the, which, what, that, nuclides, a, hollingworth,
# Nearest to the: a, their, its, this, his, our, her, crossings,
# Nearest to were: are, was, had, is, have, been, include, conjunctivitis,
# Nearest to united: parishes, aground, ante, remastered, caches, defends, krupp, ecb,
# Nearest to as: became, portland, carroll, vre, nameless, airborne, laramie, inbound,
# Nearest to history: list, partisan, museum, msp, interfered, poisons, consists, cigars,
# Nearest to been: become, come, be, were, altruistic, kauravas, preferentially, gurevich,
# Nearest to it: she, he, this, there, what, mitterrand, mobilize, participating,
# Average loss at step 32000: 3.006400
# Average loss at step 34000: 3.202048
# Average loss at step 36000: 3.200533
# Average loss at step 38000: 3.143891
# Average loss at step 40000: 3.162194
# Nearest to nine: eight, six, seven, five, four, zero, two, three,
# Nearest to its: their, his, her, the, your, s, satirized, resigns,
# Nearest to while: and, although, however, but, including, among, though, ntsc,
# Nearest to by: jelly, using, carbamazepine, when, who, inlet, operatives, tying,
# Nearest to an: another, a, the, bard, commemorations, alcs, kw, firestorm,
# Nearest to zero: eight, four, five, six, seven, three, two, nine,
# Nearest to his: her, their, its, my, your, the, our, keypad,
# Nearest to that: which, however, termination, although, where, when, vic, this,
# Nearest to this: it, which, the, he, what, she, another, that,
# Nearest to the: a, its, this, their, crossings, an, his, these,
# Nearest to were: are, was, had, is, being, have, became, include,
# Nearest to united: parishes, ecb, defends, ante, carolla, missoula, transformer, folds,
# Nearest to as: glasgow, before, marino, liz, airborne, carroll, imitative, nameless,
# Nearest to history: consists, episode, philosophy, series, coronary, endocarditis, roden, version,
# Nearest to been: become, come, was, be, occurred, preferentially, kauravas, deregulation,
# Nearest to it: he, this, she, there, uwe, mobilize, rout, what,
# Average loss at step 42000: 3.203278
# Average loss at step 44000: 3.140750
# Average loss at step 46000: 3.135023
# Average loss at step 48000: 3.060430
# Average loss at step 50000: 3.051261
# Nearest to nine: eight, seven, six, zero, five, four, three, two,
# Nearest to its: their, his, the, her, your, crone, derry, satirized,
# Nearest to while: although, however, including, where, among, when, though, and,
# Nearest to by: through, without, jelly, ccp, carbamazepine, operatives, roach, under,
# Nearest to an: another, the, vasili, a, kw, any, electrification, firestorm,
# Nearest to zero: seven, eight, five, six, nine, four, three, two,
# Nearest to his: her, their, its, the, your, my, s, keypad,
# Nearest to that: which, however, although, where, who, how, cti, termination,
# Nearest to this: which, another, crumbled, what, intuitionism, it, the, a,
# Nearest to the: its, his, a, an, their, crossings, another, any,
# Nearest to were: are, was, being, is, have, include, had, be,
# Nearest to united: ecb, gambia, heartfelt, missoula, parishes, uk, pension, member,
# Nearest to as: hund, ctesiphon, carroll, easterly, waterborne, how, nameless, nikola,
# Nearest to history: list, modern, consists, hilbert, gc, techno, knossos, pacified,
# Nearest to been: become, occurred, come, gone, begun, reordering, remained, kauravas,
# Nearest to it: he, she, mobilize, there, this, uwe, still, crouch,
# Average loss at step 52000: 3.093709
# Average loss at step 54000: 3.093048
# Average loss at step 56000: 2.918887
# Average loss at step 58000: 3.029626
# Average loss at step 60000: 3.048979
# Nearest to nine: eight, five, seven, six, zero, four, three, two,
# Nearest to its: their, his, her, the, our, edsac, your, a,
# Nearest to while: although, and, though, however, but, ahura, among, where,
# Nearest to by: through, under, jelly, carbamazepine, against, mascarene, from, personas,
# Nearest to an: another, the, a, archie, electrification, this, trombones, pital,
# Nearest to zero: eight, five, six, seven, four, three, nine, million,
# Nearest to his: her, their, its, your, s, my, our, the,
# Nearest to that: which, what, whose, however, itself, where, lewinsky, iww,
# Nearest to this: it, which, another, the, every, what, an, a,
# Nearest to the: its, a, his, their, an, another, our, this,
# Nearest to were: are, was, is, yb, include, being, mordechai, several,
# Nearest to united: member, ecb, pension, gambia, confederate, irreducibly, ante, heartfelt,
# Nearest to as: hynek, overlord, ctesiphon, pestilence, negotiate, vikernes, hijackers, chukchi,
# Nearest to history: list, hilbert, philosophy, republic, medicine, journal, poisons, museum,
# Nearest to been: become, come, occurred, gone, thursdays, riders, gurevich, him,
# Nearest to it: he, she, this, there, uwe, mobilize, computed, creeds,
# Average loss at step 62000: 3.005840
# Average loss at step 64000: 2.922350
# Average loss at step 66000: 2.929339
# Average loss at step 68000: 2.964932
# Average loss at step 70000: 3.008110
# Nearest to nine: eight, th, zero, january, seven, december, march, july,
# Nearest to its: their, his, her, the, our, your, both, s,
# Nearest to while: although, though, when, however, and, but, rooftops, before,
# Nearest to by: through, tying, had, inteligencia, when, jelly, originally, among,
# Nearest to an: another, any, electrification, archie, firestorm, pital, the, vasili,
# Nearest to zero: five, eight, two, six, three, four, nine, seven,
# Nearest to his: their, her, its, your, s, my, our, the,
# Nearest to that: which, where, nevertheless, what, termination, this, vic, because,
# Nearest to this: another, it, which, clarifying, mercia, seasoning, hollingworth, baptisms,
# Nearest to the: their, its, a, his, our, any, crossings, anthemius,
# Nearest to were: are, was, is, include, had, have, be, yue,
# Nearest to united: confederate, shires, ecb, heartfelt, interviewer, signalling, dioxin, ante,
# Nearest to as: laramie, luk, pestilence, mpc, vikernes, showered, vre, bertha,
# Nearest to history: benoit, concept, deuterium, modern, origin, list, journal, fungus,
# Nearest to been: become, gone, come, remained, gurevich, thinning, be, was,
# Nearest to it: he, she, this, airships, myr, they, kio, pneumonia,
# Average loss at step 72000: 2.940598
# Average loss at step 74000: 2.866572
# Average loss at step 76000: 2.994656
# Average loss at step 78000: 3.004623
# Average loss at step 80000: 2.839854
# Nearest to nine: eight, seven, zero, six, three, four, five, september,
# Nearest to its: their, his, her, the, your, tariffs, fliers, my,
# Nearest to while: though, when, although, where, before, however, if, after,
# Nearest to by: ccp, lends, through, abruzzo, in, parted, bidirectional, gilchrist,
# Nearest to an: another, pital, pentecostalism, the, archie, kw, firestorm, any,
# Nearest to zero: seven, five, eight, six, three, nine, four, two,
# Nearest to his: her, their, its, your, my, s, the, lovejoy,
# Nearest to that: which, what, where, how, this, however, nevertheless, although,
# Nearest to this: it, which, what, that, crumbled, a, the, sometimes,
# Nearest to the: its, their, his, a, another, your, our, any,
# Nearest to were: are, was, is, include, had, various, have, exist,
# Nearest to united: confederate, shires, carolla, irreducibly, csm, ante, interviewer, pianos,
# Nearest to as: without, sporadically, overlord, vre, token, became, like, hynek,
# Nearest to history: list, geography, biography, map, survey, consists, rams, vijay,
# Nearest to been: become, come, occurred, begun, increased, thursdays, appeared, gone,
# Nearest to it: he, she, this, there, mitterrand, censuses, distaste, they,
# Average loss at step 82000: 2.938233
# Average loss at step 84000: 2.902472
# Average loss at step 86000: 2.916727
# Average loss at step 88000: 2.946954
# Average loss at step 90000: 2.839394
# Nearest to nine: seven, eight, six, zero, th, five, four, two,
# Nearest to its: their, his, the, her, your, whose, our, carly,
# Nearest to while: although, though, when, and, where, however, before, among,
# Nearest to by: through, from, maternal, gilchrist, tying, dona, swann, gershom,
# Nearest to an: another, the, any, firestorm, archie, pital, alcs, commemorations,
# Nearest to zero: five, six, eight, nine, four, seven, three, two,
# Nearest to his: its, their, her, your, my, whose, the, lovejoy,
# Nearest to that: which, what, when, this, discordian, remini, colloquium, strongly,
# Nearest to this: another, what, it, which, a, that, any, the,
# Nearest to the: its, a, any, their, an, his, another, crossings,
# Nearest to were: are, was, had, have, include, is, represent, telekinesis,
# Nearest to united: confederate, csm, irreducibly, shires, beep, ecb, defends, heartfelt,
# Nearest to as: discrepancy, mpc, carroll, nameless, luk, livecd, corrupting, hund,
# Nearest to history: list, journal, consists, collection, map, consisting, origin, establishment,
# Nearest to been: become, begun, evolved, gone, occurred, thursdays, fallen, come,
# Nearest to it: he, she, there, this, fcc, censuses, only, they,
# Average loss at step 92000: 2.903713
# Average loss at step 94000: 2.884489
# Average loss at step 96000: 2.713727
# Average loss at step 98000: 2.454829
# Average loss at step 100000: 2.706206
# Nearest to nine: eight, six, seven, five, zero, june, four, three,
# Nearest to its: their, his, her, the, provincia, our, your, satirized,
# Nearest to while: although, though, when, and, however, knocked, tensor, ntsc,
# Nearest to by: thus, through, with, via, roach, shih, including, swann,
# Nearest to an: another, alcs, any, celestines, pital, firestorm, archie, pentecostalism,
# Nearest to zero: five, eight, six, seven, four, nine, three, million,
# Nearest to his: her, their, its, my, your, s, our, whose,
# Nearest to that: which, where, when, if, although, vic, however, strongly,
# Nearest to this: which, another, some, it, every, main, zack, melanesian,
# Nearest to the: its, a, any, their, his, her, another, each,
# Nearest to were: are, was, being, include, is, had, have, be,
# Nearest to united: confederate, csm, us, inquiring, ultimate, shires, mariam, ecb,
# Nearest to as: ctesiphon, hund, advising, tupi, pestilence, kampaku, nameless, wilhelmina,
# Nearest to history: list, origin, philosophy, journal, mission, origins, literature, benoit,
# Nearest to been: become, gone, begun, evolved, occurred, come, fallen, existed,
# Nearest to it: she, he, this, fcc, slowly, censuses, ithaca, sutter,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
